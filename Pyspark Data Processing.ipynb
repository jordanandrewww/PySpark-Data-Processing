# %%
from pyspark.sql.functions import col, when, avg, count, sum as _sum, max, min, stddev, substring

import time

# Check Spark version and cluster info
print(f"Spark version: {spark.version}")
print(f"Cluster configured successfully!")
# Out:
# Spark version: 4.0.0
# Cluster configured successfully!

# %%
# Create large dataset by duplicating
print("Creating large dataset (10x duplication)...")

df_base = spark.read.csv("/databricks-datasets/flights/departuredelays.csv", 
                          header=True, inferSchema=True)

df_large = df_base
for i in range(9):
    df_large = df_large.union(df_base)

print("Created ~1 GB dataset with 14M rows")
# Out:
# Creating large dataset (10x duplication)...
# Created ~1 GB dataset with 14M rows

# %%
# applies 3 filters to make it so we only have rows that originated from SFO, 
# had a delay of more than 60 minutes, and flew more than 500 miles
filtered_df = (
    df_base
    .filter(col("origin") == "SFO")
    .filter(col("delay") > 60)
    .filter(col("distance") > 500)
)

print(f"Filtered rows: {filtered_df.count():,}")

# using .withColumn to add a column named "delay_category"
transformed_df = (
    filtered_df
    .withColumn(
        "delay_category",
        when(col("delay") >= 180, "Severe Delay")
        .when((col("delay") >= 60) & (col("delay") < 180), "Moderate Delay")
        .otherwise("Minor or No Delay")
    )
)

# Repartition before heavy aggregations
transformed_df = transformed_df.repartition(8, "delay_category")
# Out:
# Filtered rows: 1,600

# %%
# my complex aggregation (since I am only using 1 dataset) that groups by destination and computes the following metrics:
# - total_flights
# - flights_with_delay
# - avg_delay
# - delay_stddev
# - max_delay
# - min_delay
complex_agg = (
    transformed_df
    .groupBy("destination")
    .agg(
        count("*").alias("total_flights"),
        _sum(when(col("delay") > 0, 1).otherwise(0)).alias("flights_with_delay"),
        avg("delay").alias("avg_delay"),
        stddev("delay").alias("delay_stddev"),
        max("delay").alias("max_delay"),
        min("delay").alias("min_delay")
    )
    .orderBy(col("avg_delay").desc())
)

display(complex_agg.limit(10))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>destination</th><th>total_flights</th><th>flights_with_delay</th><th>avg_delay</th><th>delay_stddev</th><th>max_delay</th><th>min_delay</th></tr></thead><tbody><tr><td>MIA</td><td>18</td><td>18</td><td>179.66666666666666</td><td>158.47100310002904</td><td>740</td><td>63</td></tr><tr><td>DTW</td><td>6</td><td>6</td><td>170.83333333333334</td><td>89.94980081504721</td><td>291</td><td>71</td></tr><tr><td>HNL</td><td>46</td><td>46</td><td>141.65217391304347</td><td>77.93507765122466</td><td>329</td><td>63</td></tr><tr><td>JFK</td><td>148</td><td>148</td><td>139.25675675675674</td><td>94.71770600889093</td><td>636</td><td>61</td></tr><tr><td>LIH</td><td>8</td><td>8</td><td>138.375</td><td>73.51372563775324</td><td>282</td><td>69</td></tr><tr><td>STL</td><td>6</td><td>6</td><td>136.0</td><td>106.81947387999999</td><td>307</td><td>62</td></tr><tr><td>ORD</td><td>138</td><td>138</td><td>134.36231884057972</td><td>143.72611535138554</td><td>1638</td><td>61</td></tr><tr><td>MSP</td><td>28</td><td>28</td><td>132.71428571428572</td><td>85.45427936875873</td><td>446</td><td>65</td></tr><tr><td>ATL</td><td>25</td><td>25</td><td>129.8</td><td>74.63075773432828</td><td>376</td><td>62</td></tr><tr><td>SUN</td><td>11</td><td>11</td><td>127.36363636363636</td><td>56.25526238010579</td><td>226</td><td>61</td></tr></tbody></table></div>

# %%
# group by delay_category and compute the following metrics:
# - avg_delay
# - num_flights
month_delay_summary = (
    transformed_df
    .groupBy("delay_category")
    .agg(
        avg("delay").alias("avg_delay"),
        count("*").alias("num_flights")
    )
    .orderBy(col("avg_delay").desc())
)

display(month_delay_summary)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>delay_category</th><th>avg_delay</th><th>num_flights</th></tr></thead><tbody><tr><td>Severe Delay</td><td>259.484693877551</td><td>196</td></tr><tr><td>Moderate Delay</td><td>100.18162393162393</td><td>1404</td></tr></tbody></table></div>

# %%
# SQL Queries

# Register as a temporary view for Spark SQL
transformed_df.createOrReplaceTempView("flight_delays")

top_delays = spark.sql("""
    SELECT destination, 
           AVG(delay) AS avg_delay, 
           COUNT(*) AS num_flights
    FROM flight_delays
    WHERE delay > 60 AND origin = 'SFO'
    GROUP BY destination
    ORDER BY avg_delay DESC
    LIMIT 10
""")

display(top_delays)

delay_category_summary = spark.sql("""
    SELECT delay_category, 
           COUNT(*) AS num_flights,
           AVG(delay) AS avg_delay
    FROM flight_delays
    GROUP BY delay_category
    ORDER BY avg_delay DESC
""")

display(delay_category_summary)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>destination</th><th>avg_delay</th><th>num_flights</th></tr></thead><tbody><tr><td>MIA</td><td>179.66666666666666</td><td>18</td></tr><tr><td>DTW</td><td>170.83333333333334</td><td>6</td></tr><tr><td>HNL</td><td>141.65217391304347</td><td>46</td></tr><tr><td>JFK</td><td>139.25675675675674</td><td>148</td></tr><tr><td>LIH</td><td>138.375</td><td>8</td></tr><tr><td>STL</td><td>136.0</td><td>6</td></tr><tr><td>ORD</td><td>134.36231884057972</td><td>138</td></tr><tr><td>MSP</td><td>132.71428571428572</td><td>28</td></tr><tr><td>ATL</td><td>129.8</td><td>25</td></tr><tr><td>SUN</td><td>127.36363636363636</td><td>11</td></tr></tbody></table></div>
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>delay_category</th><th>num_flights</th><th>avg_delay</th></tr></thead><tbody><tr><td>Severe Delay</td><td>196</td><td>259.484693877551</td></tr><tr><td>Moderate Delay</td><td>1404</td><td>100.18162393162393</td></tr></tbody></table></div>

# %%
# Writing query results to a table

# top_delays DataFrame → managed table
top_delays.write.mode("overwrite").saveAsTable("top_delays_table")

# delay_category_summary DataFrame → managed table
delay_category_summary.write.mode("overwrite").saveAsTable("delay_category_summary_table")

# %%
# Explain
filtered_df.explain(True)
transformed_df.explain(True)
complex_agg.explain(True)
month_delay_summary.explain(True)
delay_category_summary.explain(True)
top_delays.explain(True)
# Out:
# == Parsed Logical Plan ==
# 'Filter '`>`('distance, 500)
# +- 'Filter '`>`('delay, 60)
#    +- 'Filter '`==`('origin, SFO)
#       +- Relation [date#14956,delay#14957,distance#14958,origin#14959,destination#14960] csv
#
# == Analyzed Logical Plan ==
# date: int, delay: int, distance: int, origin: string, destination: string
# Filter (distance#14958 > 500)
# +- Filter (delay#14957 > 60)
#    +- Filter (origin#14959 = SFO)
#       +- Relation [date#14956,delay#14957,distance#14958,origin#14959,destination#14960] csv
#
# == Optimized Logical Plan ==
# Filter (((((isnotnull(delay#14957) AND isnotnull(distance#14958)) AND (delay#14957 > 60)) AND (distance#14958 > 500)) AND isnotnull(origin#14959)) AND (origin#14959 = SFO))
# +- Relation [date#14956,delay#14957,distance#14958,origin#14959,destination#14960] csv
#
# == Physical Plan ==
# *(1) ColumnarToRow
# +- PhotonResultStage
#    +- PhotonFilter (((((isnotnull(delay#14957) AND isnotnull(distance#14958)) AND (delay#14957 > 60)) AND (distance#14958 > 500)) AND isnotnull(origin#14959)) AND (origin#14959 = SFO))
#       +- PhotonRowToColumnar
#          +- FileScan csv [date#14956,delay#14957,distance#14958,origin#14959,destination#14960] Batched: false, DataFilters: [isnotnull(delay#14957), isnotnull(distance#14958), (delay#14957 > 60), (distance#14958 > 500), i..., Format: CSV, Location: InMemoryFileIndex(1 paths)[dbfs:/databricks-datasets/flights/departuredelays.csv], PartitionFilters: [], PushedFilters: [IsNotNull(delay), IsNotNull(distance), GreaterThan(delay,60), GreaterThan(distance,500), IsNotNu..., ReadSchema: struct<date:int,delay:int,distance:int,origin:string,destination:string>
#
# == Photon Explanation ==
# The query is fully supported by Photon.
# == Parsed Logical Plan ==
# 'RepartitionByExpression ['delay_category], 8
# +- Project [date#14956, delay#14957, distance#14958, origin#14959, destination#14960, CASE WHEN (delay#14957 >= 180) THEN Severe Delay WHEN ((delay#14957 >= 60) AND (delay#14957 < 180)) THEN Moderate Delay ELSE Minor or No Delay END AS delay_category#15018]
#    +- Filter (distance#14958 > 500)
#       +- Filter (delay#14957 > 60)
#          +- Filter (origin#14959 = SFO)
#             +- Relation [date#14956,delay#14957,distance#14958,origin#14959,destination#14960] csv
#
# == Analyzed Logical Plan ==
# date: int, delay: int, distance: int, origin: string, destination: string, delay_category: string
# RepartitionByExpression [delay_category#15018], 8
# +- Project [date#14956, delay#14957, distance#14958, origin#14959, destination#14960, CASE WHEN (delay#14957 >= 180) THEN Severe Delay WHEN ((delay#14957 >= 60) AND (delay#14957 < 180)) THEN Moderate Delay ELSE Minor or No Delay END AS delay_category#15018]
#    +- Filter (distance#14958 > 500)
#       +- Filter (delay#14957 > 60)
#          +- Filter (origin#14959 = SFO)
#             +- Relation [date#14956,delay#14957,distance#14958,origin#14959,destination#14960] csv
#
# == Optimized Logical Plan ==
# RepartitionByExpression [delay_category#15018], 8
# +- Project [date#14956, delay#14957, distance#14958, origin#14959, destination#14960, CASE WHEN (delay#14957 >= 180) THEN Severe Delay WHEN ((delay#14957 >= 60) AND (delay#14957 < 180)) THEN Moderate Delay ELSE Minor or No Delay END AS delay_category#15018]
#    +- Filter (((((isnotnull(delay#14957) AND isnotnull(distance#14958)) AND (delay#14957 > 60)) AND (distance#14958 > 500)) AND isnotnull(origin#14959)) AND (origin#14959 = SFO))
#       +- Relation [date#14956,delay#14957,distance#14958,origin#14959,destination#14960] csv
#
# == Physical Plan ==
# AdaptiveSparkPlan isFinalPlan=false
# +- == Initial Plan ==
#    ColumnarToRow
#    +- PhotonResultStage
#       +- PhotonShuffleExchangeSource
#          +- PhotonShuffleMapStage REPARTITION_BY_NUM, [id=#16635]
#             +- PhotonShuffleExchangeSink hashpartitioning(delay_category#15018, 8)
#                +- PhotonProject [date#14956, delay#14957, distance#14958, origin#14959, destination#14960, CASE WHEN (delay#14957 >= 180) THEN Severe Delay WHEN ((delay#14957 >= 60) AND (delay#14957 < 180)) THEN Moderate Delay ELSE Minor or No Delay END AS delay_category#15018]
#                   +- PhotonFilter (((((isnotnull(delay#14957) AND isnotnull(distance#14958)) AND (delay#14957 > 60)) AND (distance#14958 > 500)) AND isnotnull(origin#14959)) AND (origin#14959 = SFO))
#                      +- PhotonRowToColumnar
#                         +- FileScan csv [date#14956,delay#14957,distance#14958,origin#14959,destination#14960] Batched: false, DataFilters: [isnotnull(delay#14957), isnotnull(distance#14958), (delay#14957 > 60), (distance#14958 > 500), i..., Format: CSV, Location: InMemoryFileIndex(1 paths)[dbfs:/databricks-datasets/flights/departuredelays.csv], PartitionFilters: [], PushedFilters: [IsNotNull(delay), IsNotNull(distance), GreaterThan(delay,60), GreaterThan(distance,500), IsNotNu..., ReadSchema: struct<date:int,delay:int,distance:int,origin:string,destination:string>
#
# == Photon Explanation ==
# The query is fully supported by Photon.
# == Parsed Logical Plan ==
# 'Sort ['avg_delay DESC NULLS LAST], true
# +- 'Aggregate ['destination], ['destination, 'count(*) AS total_flights#15316, 'sum('when('`>`('delay, 0), 1, 0)) AS flights_with_delay#15317, 'avg('delay) AS avg_delay#15318, 'stddev('delay) AS delay_stddev#15319, 'max('delay) AS max_delay#15320, 'min('delay) AS min_delay#15321]
#    +- 'RepartitionByExpression ['delay_category], 8
#       +- Project [date#14956, delay#14957, distance#14958, origin#14959, destination#14960, CASE WHEN (delay#14957 >= 180) THEN Severe Delay WHEN ((delay#14957 >= 60) AND (delay#14957 < 180)) THEN Moderate Delay ELSE Minor or No Delay END AS delay_category#15018]
#          +- Filter (distance#14958 > 500)
#             +- Filter (delay#14957 > 60)
#                +- Filter (origin#14959 = SFO)
#                   +- Relation [date#14956,delay#14957,distance#14958,origin#14959,destination#14960] csv
#
# == Analyzed Logical Plan ==
# destination: string, total_flights: bigint, flights_with_delay: bigint, avg_delay: double, delay_stddev: double, max_delay: int, min_delay: int
# Sort [avg_delay#15318 DESC NULLS LAST], true
# +- Aggregate [destination#14960], [destination#14960, count(1) AS total_flights#15316L, sum(CASE WHEN (delay#14957 > 0) THEN 1 ELSE 0 END) AS flights_with_delay#15317L, avg(delay#14957) AS avg_delay#15318, stddev(cast(delay#14957 as double)) AS delay_stddev#15319, max(delay#14957) AS max_delay#15320, min(delay#14957) AS min_delay#15321]
#    +- RepartitionByExpression [delay_category#15018], 8
#       +- Project [date#14956, delay#14957, distance#14958, origin#14959, destination#14960, CASE WHEN (delay#14957 >= 180) THEN Severe Delay WHEN ((delay#14957 >= 60) AND (delay#14957 < 180)) THEN Moderate Delay ELSE Minor or No Delay END AS delay_category#15018]
#          +- Filter (distance#14958 > 500)
#             +- Filter (delay#14957 > 60)
#                +- Filter (origin#14959 = SFO)
#                   +- Relation [date#14956,delay#14957,distance#14958,origin#14959,destination#14960] csv
#
# == Optimized Logical Plan ==
# Sort [avg_delay#15318 DESC NULLS LAST], true
# +- Aggregate [destination#14960], [destination#14960, count(1) AS total_flights#15316L, sum(CASE WHEN (delay#14957 > 0) THEN 1 ELSE 0 END) AS flights_with_delay#15317L, avg(delay#14957) AS avg_delay#15318, stddev(cast(delay#14957 as double)) AS delay_stddev#15319, max(delay#14957) AS max_delay#15320, min(delay#14957) AS min_delay#15321]
#    +- Project [delay#14957, destination#14960]
#       +- RepartitionByExpression [delay_category#15018], 8
#          +- Project [delay#14957, destination#14960, CASE WHEN (delay#14957 >= 180) THEN Severe Delay WHEN ((delay#14957 >= 60) AND (delay#14957 < 180)) THEN Moderate Delay ELSE Minor or No Delay END AS delay_category#15018]
#             +- Filter (((((isnotnull(delay#14957) AND isnotnull(distance#14958)) AND (delay#14957 > 60)) AND (distance#14958 > 500)) AND isnotnull(origin#14959)) AND (origin#14959 = SFO))
#                +- Relation [date#14956,delay#14957,distance#14958,origin#14959,destination#14960] csv
#
# == Physical Plan ==
# AdaptiveSparkPlan isFinalPlan=false
# +- == Initial Plan ==
#    ColumnarToRow
#    +- PhotonResultStage
#       +- PhotonSort [avg_delay#15318 DESC NULLS LAST]
#          +- PhotonShuffleExchangeSource
#             +- PhotonShuffleMapStage ENSURE_REQUIREMENTS, [id=#16814]
#                +- PhotonShuffleExchangeSink rangepartitioning(avg_delay#15318 DESC NULLS LAST, 16)
#                   +- PhotonGroupingAgg(limit=None, keys=[destination#14960], functions=[finalmerge_count(merge count#16005L) AS count(1)#15950L, finalmerge_sum(merge sum#16007L) AS sum(CASE WHEN (delay > 0) THEN 1 ELSE 0 END)#15951L, finalmerge_avg(merge sum#16010, count#16011L) AS avg(delay)#15952, finalmerge_stddev(merge n#15985, avg#15986, m2#15987) AS stddev(delay)#15961, finalmerge_max(merge max#16013) AS max(delay)#15962, finalmerge_min(merge min#16015) AS min(delay)#15963], output=[destination#14960, total_flights#15316L, flights_with_delay#15317L, avg_delay#15318, delay_stddev#15319, max_delay#15320, min_delay#15321])
#                      +- PhotonShuffleExchangeSource
#                         +- PhotonShuffleMapStage ENSURE_REQUIREMENTS, [id=#16808]
#                            +- PhotonShuffleExchangeSink hashpartitioning(destination#14960, 1024)
#                               +- PhotonGroupingAgg(limit=None, keys=[destination#14960], functions=[partial_count(1) AS count#16005L, partial_sum(CASE WHEN (delay#14957 > 0) THEN 1 ELSE 0 END) AS sum#16007L, partial_avg(delay#14957) AS (sum#16010, count#16011L), partial_stddev(cast(delay#14957 as double)) AS (n#15985, avg#15986, m2#15987), partial_max(delay#14957) AS max#16013, partial_min(delay#14957) AS min#16015], output=[destination#14960, count#16005L, sum#16007L, sum#16010, count#16011L, n#15985, avg#15986, m2#15987, max#16013, min#16015])
#                                  +- PhotonProject [delay#14957, destination#14960]
#                                     +- PhotonShuffleExchangeSource
#                                        +- PhotonShuffleMapStage REPARTITION_BY_NUM, [id=#16800]
#                                           +- PhotonShuffleExchangeSink hashpartitioning(delay_category#15018, 8)
#                                              +- PhotonProject [delay#14957, destination#14960, CASE WHEN (delay#14957 >= 180) THEN Severe Delay WHEN ((delay#14957 >= 60) AND (delay#14957 < 180)) THEN Moderate Delay ELSE Minor or No Delay END AS delay_category#15018]
#                                                 +- PhotonFilter (((((isnotnull(delay#14957) AND isnotnull(distance#14958)) AND (delay#14957 > 60)) AND (distance#14958 > 500)) AND isnotnull(origin#14959)) AND (origin#14959 = SFO))
#                                                    +- PhotonRowToColumnar
#                                                       +- FileScan csv [delay#14957,distance#14958,origin#14959,destination#14960] Batched: false, DataFilters: [isnotnull(delay#14957), isnotnull(distance#14958), (delay#14957 > 60), (distance#14958 > 500), i..., Format: CSV, Location: InMemoryFileIndex(1 paths)[dbfs:/databricks-datasets/flights/departuredelays.csv], PartitionFilters: [], PushedFilters: [IsNotNull(delay), IsNotNull(distance), GreaterThan(delay,60), GreaterThan(distance,500), IsNotNu..., ReadSchema: struct<delay:int,distance:int,origin:string,destination:string>
#
# == Photon Explanation ==
# The query is fully supported by Photon.
# == Parsed Logical Plan ==
# 'Sort ['avg_delay DESC NULLS LAST], true
# +- 'Aggregate ['delay_category], ['delay_category, 'avg('delay) AS avg_delay#15369, 'count(*) AS num_flights#15370]
#    +- 'RepartitionByExpression ['delay_category], 8
#       +- Project [date#14956, delay#14957, distance#14958, origin#14959, destination#14960, CASE WHEN (delay#14957 >= 180) THEN Severe Delay WHEN ((delay#14957 >= 60) AND (delay#14957 < 180)) THEN Moderate Delay ELSE Minor or No Delay END AS delay_category#15018]
#          +- Filter (distance#14958 > 500)
#             +- Filter (delay#14957 > 60)
#                +- Filter (origin#14959 = SFO)
#                   +- Relation [date#14956,delay#14957,distance#14958,origin#14959,destination#14960] csv
#
# == Analyzed Logical Plan ==
# delay_category: string, avg_delay: double, num_flights: bigint
# Sort [avg_delay#15369 DESC NULLS LAST], true
# +- Aggregate [delay_category#15018], [delay_category#15018, avg(delay#14957) AS avg_delay#15369, count(1) AS num_flights#15370L]
#    +- RepartitionByExpression [delay_category#15018], 8
#       +- Project [date#14956, delay#14957, distance#14958, origin#14959, destination#14960, CASE WHEN (delay#14957 >= 180) THEN Severe Delay WHEN ((delay#14957 >= 60) AND (delay#14957 < 180)) THEN Moderate Delay ELSE Minor or No Delay END AS delay_category#15018]
#          +- Filter (distance#14958 > 500)
#             +- Filter (delay#14957 > 60)
#                +- Filter (origin#14959 = SFO)
#                   +- Relation [date#14956,delay#14957,distance#14958,origin#14959,destination#14960] csv
#
# == Optimized Logical Plan ==
# Sort [avg_delay#15369 DESC NULLS LAST], true
# +- Aggregate [delay_category#15018], [delay_category#15018, avg(delay#14957) AS avg_delay#15369, count(1) AS num_flights#15370L]
#    +- RepartitionByExpression [delay_category#15018], 8
#       +- Project [delay#14957, CASE WHEN (delay#14957 >= 180) THEN Severe Delay WHEN ((delay#14957 >= 60) AND (delay#14957 < 180)) THEN Moderate Delay ELSE Minor or No Delay END AS delay_category#15018]
#          +- Filter (((((isnotnull(delay#14957) AND isnotnull(distance#14958)) AND (delay#14957 > 60)) AND (distance#14958 > 500)) AND isnotnull(origin#14959)) AND (origin#14959 = SFO))
#             +- Relation [date#14956,delay#14957,distance#14958,origin#14959,destination#14960] csv
#
# == Physical Plan ==
# AdaptiveSparkPlan isFinalPlan=false
# +- == Initial Plan ==
#    ColumnarToRow
#    +- PhotonResultStage
#       +- PhotonSort [avg_delay#15369 DESC NULLS LAST]
#          +- PhotonShuffleExchangeSource
#             +- PhotonShuffleMapStage ENSURE_REQUIREMENTS, [id=#16950]
#                +- PhotonShuffleExchangeSink rangepartitioning(avg_delay#15369 DESC NULLS LAST, 16)
#                   +- PhotonGroupingAgg(limit=None, keys=[delay_category#15018], functions=[avg(delay#14957), count(1)], output=[delay_category#15018, avg_delay#15369, num_flights#15370L])
#                      +- PhotonShuffleExchangeSource
#                         +- PhotonShuffleMapStage REPARTITION_BY_NUM, [id=#16944]
#                            +- PhotonShuffleExchangeSink hashpartitioning(delay_category#15018, 8)
#                               +- PhotonProject [delay#14957, CASE WHEN (delay#14957 >= 180) THEN Severe Delay WHEN ((delay#14957 >= 60) AND (delay#14957 < 180)) THEN Moderate Delay ELSE Minor or No Delay END AS delay_category#15018]
#                                  +- PhotonFilter (((((isnotnull(delay#14957) AND isnotnull(distance#14958)) AND (delay#14957 > 60)) AND (distance#14958 > 500)) AND isnotnull(origin#14959)) AND (origin#14959 = SFO))
#                                     +- PhotonRowToColumnar
#                                        +- FileScan csv [delay#14957,distance#14958,origin#14959] Batched: false, DataFilters: [isnotnull(delay#14957), isnotnull(distance#14958), (delay#14957 > 60), (distance#14958 > 500), i..., Format: CSV, Location: InMemoryFileIndex(1 paths)[dbfs:/databricks-datasets/flights/departuredelays.csv], PartitionFilters: [], PushedFilters: [IsNotNull(delay), IsNotNull(distance), GreaterThan(delay,60), GreaterThan(distance,500), IsNotNu..., ReadSchema: struct<delay:int,distance:int,origin:string>
#
# == Photon Explanation ==
# The query is fully supported by Photon.
# == Parsed Logical Plan ==
# 'Sort ['avg_delay DESC NULLS LAST], true
# +- 'Aggregate ['delay_category], ['delay_category, 'COUNT(1) AS num_flights#15458, 'AVG('delay) AS avg_delay#15459]
#    +- 'UnresolvedRelation [flight_delays], [], false
#
# == Analyzed Logical Plan ==
# delay_category: string, num_flights: bigint, avg_delay: double
# Sort [avg_delay#15459 DESC NULLS LAST], true
# +- Aggregate [delay_category#15018], [delay_category#15018, count(1) AS num_flights#15458L, avg(delay#14957) AS avg_delay#15459]
#    +- SubqueryAlias flight_delays
#       +- View (`flight_delays`, [date#14956, delay#14957, distance#14958, origin#14959, destination#14960, delay_category#15018])
#          +- RepartitionByExpression [delay_category#15018], 8
#             +- Project [date#14956, delay#14957, distance#14958, origin#14959, destination#14960, CASE WHEN (delay#14957 >= 180) THEN Severe Delay WHEN ((delay#14957 >= 60) AND (delay#14957 < 180)) THEN Moderate Delay ELSE Minor or No Delay END AS delay_category#15018]
#                +- Filter (distance#14958 > 500)
#                   +- Filter (delay#14957 > 60)
#                      +- Filter (origin#14959 = SFO)
#                         +- Relation [date#14956,delay#14957,distance#14958,origin#14959,destination#14960] csv
#
# == Optimized Logical Plan ==
# Sort [avg_delay#15459 DESC NULLS LAST], true
# +- Aggregate [delay_category#15018], [delay_category#15018, count(1) AS num_flights#15458L, avg(delay#14957) AS avg_delay#15459]
#    +- RepartitionByExpression [delay_category#15018], 8
#       +- Project [delay#14957, CASE WHEN (delay#14957 >= 180) THEN Severe Delay WHEN ((delay#14957 >= 60) AND (delay#14957 < 180)) THEN Moderate Delay ELSE Minor or No Delay END AS delay_category#15018]
#          +- Filter (((((isnotnull(delay#14957) AND isnotnull(distance#14958)) AND (delay#14957 > 60)) AND (distance#14958 > 500)) AND isnotnull(origin#14959)) AND (origin#14959 = SFO))
#             +- Relation [date#14956,delay#14957,distance#14958,origin#14959,destination#14960] csv
#
# == Physical Plan ==
# AdaptiveSparkPlan isFinalPlan=false
# +- == Initial Plan ==
#    ColumnarToRow
#    +- PhotonResultStage
#       +- PhotonSort [avg_delay#15459 DESC NULLS LAST]
#          +- PhotonShuffleExchangeSource
#             +- PhotonShuffleMapStage ENSURE_REQUIREMENTS, [id=#17078]
#                +- PhotonShuffleExchangeSink rangepartitioning(avg_delay#15459 DESC NULLS LAST, 16)
#                   +- PhotonGroupingAgg(limit=None, keys=[delay_category#15018], functions=[count(1), avg(delay#14957)], output=[delay_category#15018, num_flights#15458L, avg_delay#15459])
#                      +- PhotonShuffleExchangeSource
#                         +- PhotonShuffleMapStage REPARTITION_BY_NUM, [id=#17072]
#                            +- PhotonShuffleExchangeSink hashpartitioning(delay_category#15018, 8)
#                               +- PhotonProject [delay#14957, CASE WHEN (delay#14957 >= 180) THEN Severe Delay WHEN ((delay#14957 >= 60) AND (delay#14957 < 180)) THEN Moderate Delay ELSE Minor or No Delay END AS delay_category#15018]
#                                  +- PhotonFilter (((((isnotnull(delay#14957) AND isnotnull(distance#14958)) AND (delay#14957 > 60)) AND (distance#14958 > 500)) AND isnotnull(origin#14959)) AND (origin#14959 = SFO))
#                                     +- PhotonRowToColumnar
#                                        +- FileScan csv [delay#14957,distance#14958,origin#14959] Batched: false, DataFilters: [isnotnull(delay#14957), isnotnull(distance#14958), (delay#14957 > 60), (distance#14958 > 500), i..., Format: CSV, Location: InMemoryFileIndex(1 paths)[dbfs:/databricks-datasets/flights/departuredelays.csv], PartitionFilters: [], PushedFilters: [IsNotNull(delay), IsNotNull(distance), GreaterThan(delay,60), GreaterThan(distance,500), IsNotNu..., ReadSchema: struct<delay:int,distance:int,origin:string>
#
# == Photon Explanation ==
# The query is fully supported by Photon.
# == Parsed Logical Plan ==
# 'GlobalLimit 10
# +- 'LocalLimit 10
#    +- 'Sort ['avg_delay DESC NULLS LAST], true
#       +- 'Aggregate ['destination], ['destination, 'AVG('delay) AS avg_delay#15407, 'COUNT(1) AS num_flights#15408]
#          +- 'Filter (('delay > 60) AND ('origin = SFO))
#             +- 'UnresolvedRelation [flight_delays], [], false
#
# == Analyzed Logical Plan ==
# destination: string, avg_delay: double, num_flights: bigint
# GlobalLimit 10
# +- LocalLimit 10
#    +- Sort [avg_delay#15407 DESC NULLS LAST], true
#       +- Aggregate [destination#14960], [destination#14960, avg(delay#14957) AS avg_delay#15407, count(1) AS num_flights#15408L]
#          +- Filter ((delay#14957 > 60) AND (origin#14959 = SFO))
#             +- SubqueryAlias flight_delays
#                +- View (`flight_delays`, [date#14956, delay#14957, distance#14958, origin#14959, destination#14960, delay_category#15018])
#                   +- RepartitionByExpression [delay_category#15018], 8
#                      +- Project [date#14956, delay#14957, distance#14958, origin#14959, destination#14960, CASE WHEN (delay#14957 >= 180) THEN Severe Delay WHEN ((delay#14957 >= 60) AND (delay#14957 < 180)) THEN Moderate Delay ELSE Minor or No Delay END AS delay_category#15018]
#                         +- Filter (distance#14958 > 500)
#                            +- Filter (delay#14957 > 60)
#                               +- Filter (origin#14959 = SFO)
#                                  +- Relation [date#14956,delay#14957,distance#14958,origin#14959,destination#14960] csv
#
# == Optimized Logical Plan ==
# GlobalLimit 10
# +- LocalLimit 10
#    +- Sort [avg_delay#15407 DESC NULLS LAST], true
#       +- Aggregate [destination#14960], [destination#14960, avg(delay#14957) AS avg_delay#15407, count(1) AS num_flights#15408L]
#          +- Project [delay#14957, destination#14960]
#             +- RepartitionByExpression [delay_category#15018], 8
#                +- Project [delay#14957, destination#14960, CASE WHEN (delay#14957 >= 180) THEN Severe Delay WHEN ((delay#14957 >= 60) AND (delay#14957 < 180)) THEN Moderate Delay ELSE Minor or No Delay END AS delay_category#15018]
#                   +- Filter (((((isnotnull(delay#14957) AND isnotnull(distance#14958)) AND (delay#14957 > 60)) AND (distance#14958 > 500)) AND isnotnull(origin#14959)) AND (origin#14959 = SFO))
#                      +- Relation [date#14956,delay#14957,distance#14958,origin#14959,destination#14960] csv
#
# == Physical Plan ==
# AdaptiveSparkPlan isFinalPlan=false
# +- == Initial Plan ==
#    ColumnarToRow
#    +- PhotonResultStage
#       +- PhotonTopK(limit=10, includeTies=false, sortOrder=[avg_delay#15407 DESC NULLS LAST], partitionOrderCount=0)
#          +- PhotonShuffleExchangeSource
#             +- PhotonShuffleMapStage ENSURE_REQUIREMENTS, [id=#17243]
#                +- PhotonShuffleExchangeSink SinglePartition
#                   +- PhotonTopK(limit=10, includeTies=false, sortOrder=[avg_delay#15407 DESC NULLS LAST], partitionOrderCount=0)
#                      +- PhotonGroupingAgg(limit=None, keys=[destination#14960], functions=[finalmerge_avg(merge sum#16160, count#16161L) AS avg(delay)#16156, finalmerge_count(merge count#16163L) AS count(1)#16157L], output=[destination#14960, avg_delay#15407, num_flights#15408L])
#                         +- PhotonShuffleExchangeSource
#                            +- PhotonShuffleMapStage ENSURE_REQUIREMENTS, [id=#17235]
#                               +- PhotonShuffleExchangeSink hashpartitioning(destination#14960, 16)
#                                  +- PhotonGroupingAgg(limit=None, keys=[destination#14960], functions=[partial_avg(delay#14957) AS (sum#16160, count#16161L), partial_count(1) AS count#16163L], output=[destination#14960, sum#16160, count#16161L, count#16163L])
#                                     +- PhotonProject [delay#14957, destination#14960]
#                                        +- PhotonShuffleExchangeSource
#                                           +- PhotonShuffleMapStage REPARTITION_BY_NUM, [id=#17227]
#                                              +- PhotonShuffleExchangeSink hashpartitioning(delay_category#15018, 8)
#                                                 +- PhotonProject [delay#14957, destination#14960, CASE WHEN (delay#14957 >= 180) THEN Severe Delay WHEN ((delay#14957 >= 60) AND (delay#14957 < 180)) THEN Moderate Delay ELSE Minor or No Delay END AS delay_category#15018]
#                                                    +- PhotonFilter (((((isnotnull(delay#14957) AND isnotnull(distance#14958)) AND (delay#14957 > 60)) AND (distance#14958 > 500)) AND isnotnull(origin#14959)) AND (origin#14959 = SFO))
#                                                       +- PhotonRowToColumnar
#                                                          +- FileScan csv [delay#14957,distance#14958,origin#14959,destination#14960] Batched: false, DataFilters: [isnotnull(delay#14957), isnotnull(distance#14958), (delay#14957 > 60), (distance#14958 > 500), i..., Format: CSV, Location: InMemoryFileIndex(1 paths)[dbfs:/databricks-datasets/flights/departuredelays.csv], PartitionFilters: [], PushedFilters: [IsNotNull(delay), IsNotNull(distance), GreaterThan(delay,60), GreaterThan(distance,500), IsNotNu..., ReadSchema: struct<delay:int,distance:int,origin:string,destination:string>
#
# == Photon Explanation ==
# The query is fully supported by Photon.

# %%
# Here, we will do a demonstration of transformations vs actions 

print("=== Demonstrating Lazy (Transformations) vs Eager (Actions) Execution ===")

# --- Load dataset (transformation) ---
df_base = spark.read.csv("/databricks-datasets/flights/departuredelays.csv", header=True, inferSchema=True)

# --- Lazy Transformation ---
start_lazy = time.time()

selected_df = long_flights_df.select("date", "origin", "destination", "distance", "delay")

end_lazy = time.time()
print(f"\nTime to define transformations (lazy): {end_lazy - start_lazy:.4f} seconds")

# --- Eager Action ---
print("\nNow performing an ACTION, which will actually trigger computation:")
start_action = time.time()
row_count = selected_df.count()
end_action = time.time()
print(f"Time for action (actual computation): {end_action - start_action:.2f} seconds")

print("We can see here that the time taken for transformations is significatly less than for actions")
# Out:
# === Demonstrating Lazy (Transformations) vs Eager (Actions) Execution ===
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File <command-8812838240569174>, line 11
#       8 # --- Lazy Transformation ---
#       9 start_lazy = time.time()
# ---> 11 selected_df = long_flights_df.select("date", "origin", "destination", "distance", "delay")
#      13 end_lazy = time.time()
#      14 print(f"\nTime to define transformations (lazy): {end_lazy - start_lazy:.4f} seconds")
#
# NameError: name 'long_flights_df' is not defined
